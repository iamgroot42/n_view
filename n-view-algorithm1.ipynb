# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import numpy as np
np.random.seed(123)

import random
random.seed(123)

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
set_session(tf.Session(config=config))

from keras.utils import plot_model
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, Flatten, BatchNormalization, Dropout, Reshape
from keras.optimizers import Adadelta
from keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import label_binarize
import cv2
import pdb
import progressbar
import os
from scipy import stats
from datasets import get_dataset
# Out:
# Using TensorFlow backend.

# %%
ds = get_dataset("bupa", 0.7, 0.25)
[L_x, L_y], U, [test_x, test_y] = ds.get_data()
U = np.array(U)
n_views = 5
views = []
for ind in range(n_views):
    views.append([np.array(L_x[ind * n_views:(ind + 1) * n_views]), np.array(L_y[ind * n_views:(ind + 1) * n_views])])
for ind in range(n_views):
    print views[ind][0].shape, views[ind][1].shape
# Out:
# (5, 6) (5, 2)
# (5, 6) (5, 2)
# (5, 6) (5, 2)
# (5, 6) (5, 2)
# (5, 6) (5, 2)

# %%
# Define Models
models = []
n_attr = views[ind][0].shape[1]
for ind in range(n_views):
    model = Sequential()
    model.add(Dense(input_shape=(n_attr,), units=n_attr / 2))
    model.add(Activation('relu'))
    model.add(Dense(units=n_attr/5))
    model.add(Activation('relu'))
    model.add(Dense(units=views[ind][1].shape[1]))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer=Adadelta(), metrics=['accuracy'])
    models.append(model)
print models[0].summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 3)                 21
# _________________________________________________________________
# activation_1 (Activation)    (None, 3)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 4
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 4
# _________________________________________________________________
# activation_3 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 29.0
# Trainable params: 29.0
# Non-trainable params: 0.0
# _________________________________________________________________
# None

# %%
# Train models on Labelled Data
for ind in range(n_views):
    models[ind].fit(views[ind][0], views[ind][1], epochs=100, batch_size = 64, validation_split = 0.2, 
              callbacks=[EarlyStopping(monitor='val_acc', patience=5)])
# Out:
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 0.6931 - acc: 1.0000 - val_loss: 0.6927 - val_acc: 1.0000
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 0.6927 - acc: 1.0000 - val_loss: 0.6922 - val_acc: 1.0000
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 0.6922 - acc: 1.0000 - val_loss: 0.6918 - val_acc: 1.0000
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 0.6918 - acc: 1.0000 - val_loss: 0.6913 - val_acc: 1.0000
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 0.6913 - acc: 1.0000 - val_loss: 0.6909 - val_acc: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 0.6909 - acc: 1.0000 - val_loss: 0.6904 - val_acc: 1.0000
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 0.6904 - acc: 1.0000 - val_loss: 0.6899 - val_acc: 1.0000
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 0.6931 - acc: 1.0000 - val_loss: 0.6927 - val_acc: 1.0000
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 0.6927 - acc: 1.0000 - val_loss: 0.6922 - val_acc: 1.0000
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 0.6922 - acc: 1.0000 - val_loss: 0.6918 - val_acc: 1.0000
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 0.6918 - acc: 1.0000 - val_loss: 0.6913 - val_acc: 1.0000
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 0.6913 - acc: 1.0000 - val_loss: 0.6909 - val_acc: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 0.6909 - acc: 1.0000 - val_loss: 0.6904 - val_acc: 1.0000
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 0.6904 - acc: 1.0000 - val_loss: 0.6899 - val_acc: 1.0000
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 5.0325 - acc: 0.2500 - val_loss: 5.6674 - val_acc: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 5.0067 - acc: 0.2500 - val_loss: 5.6021 - val_acc: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 4.9812 - acc: 0.2500 - val_loss: 5.5375 - val_acc: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 4.9562 - acc: 0.2500 - val_loss: 5.4740 - val_acc: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 4.9319 - acc: 0.2500 - val_loss: 5.4117 - val_acc: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 4.9120 - acc: 0.2500 - val_loss: 5.3505 - val_acc: 0.0000e+00
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 4.8928 - acc: 0.2500 - val_loss: 5.2904 - val_acc: 0.0000e+00
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 0.6931 - acc: 1.0000 - val_loss: 0.6927 - val_acc: 1.0000
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 0.6927 - acc: 1.0000 - val_loss: 0.6922 - val_acc: 1.0000
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 0.6922 - acc: 1.0000 - val_loss: 0.6918 - val_acc: 1.0000
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 0.6918 - acc: 1.0000 - val_loss: 0.6913 - val_acc: 1.0000
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 0.6913 - acc: 1.0000 - val_loss: 0.6909 - val_acc: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 0.6909 - acc: 1.0000 - val_loss: 0.6904 - val_acc: 1.0000
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 0.6904 - acc: 1.0000 - val_loss: 0.6899 - val_acc: 1.0000
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 11.5430 - acc: 0.0000e+00 - val_loss: 10.7484 - val_acc: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 11.4646 - acc: 0.0000e+00 - val_loss: 10.6740 - val_acc: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 11.3855 - acc: 0.0000e+00 - val_loss: 10.5994 - val_acc: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 11.3063 - acc: 0.0000e+00 - val_loss: 10.5247 - val_acc: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 11.2270 - acc: 0.0000e+00 - val_loss: 10.4500 - val_acc: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 11.1478 - acc: 0.0000e+00 - val_loss: 10.3755 - val_acc: 0.0000e+00
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 11.0687 - acc: 0.0000e+00 - val_loss: 10.3012 - val_acc: 0.0000e+00

# %%
# Run Co-Training Algorithm 1
# Simple majority voting over all the classifiers for the unlabelled example
L = views[0]
for ind in range(1, n_views):
    L[0] = np.concatenate([L[0], views[ind][0]], axis = 0)
    L[1] = np.concatenate([L[1], views[ind][1]], axis = 0)
changed = False
pred_modes = None
preds = np.zeros((U.shape[0], n_views))
for ind in range(n_views):
    preds[:, ind] = np.argmax(models[ind].predict(U), axis = 1)
while (not changed):
    pred_modes_new, counts = stats.mode(preds, axis=1)
    if pred_modes_new != pred_modes:
        changed = True
        pred_modes = pred_modes_new
        sel = np.array(np.argmax(pred_modes, axis=0), dtype=int)
        sel_one_hot = label_binarize([pred_modes[sel].squeeze()], classes=range(len(L_y[0]) + 1))[:, :-1]
        print sel_one_hot
        L[0] = np.concatenate([L[0], U[sel]], axis = 0)
        L[1] = np.concatenate([L[1], sel_one_hot], axis = 0)
    for ind in range(n_views):
        models[ind].fit(L[0], L[1], epochs=100, batch_size = 64, validation_split = 0.2, 
              callbacks=[EarlyStopping(monitor='val_acc', patience=5)])
perf = [None for _ in range(n_views)]
for ind in range(n_views):
    perf[ind] = model.evaluate(np.array(test_x), np.array(test_y))
    print perf[ind]
# Out:
# [[1 0]]
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 0.6899 - acc: 1.0000 - val_loss: 0.6895 - val_acc: 1.0000
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 0.6895 - acc: 1.0000 - val_loss: 0.6890 - val_acc: 1.0000
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 0.6890 - acc: 1.0000 - val_loss: 0.6885 - val_acc: 1.0000
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 0.6885 - acc: 1.0000 - val_loss: 0.6881 - val_acc: 1.0000
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 0.6881 - acc: 1.0000 - val_loss: 0.6876 - val_acc: 1.0000
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 0.6876 - acc: 1.0000 - val_loss: 0.6871 - val_acc: 1.0000
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 0.6871 - acc: 1.0000 - val_loss: 0.6867 - val_acc: 1.0000
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 0.6899 - acc: 1.0000 - val_loss: 0.6895 - val_acc: 1.0000
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 0.6895 - acc: 1.0000 - val_loss: 0.6890 - val_acc: 1.0000
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 0.6890 - acc: 1.0000 - val_loss: 0.6885 - val_acc: 1.0000
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 0.6885 - acc: 1.0000 - val_loss: 0.6881 - val_acc: 1.0000
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 0.6881 - acc: 1.0000 - val_loss: 0.6876 - val_acc: 1.0000
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 0.6876 - acc: 1.0000 - val_loss: 0.6871 - val_acc: 1.0000
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 0.6871 - acc: 1.0000 - val_loss: 0.6867 - val_acc: 1.0000
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 4.0317 - acc: 0.3500 - val_loss: 6.7737 - val_acc: 0.1667
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 3.9771 - acc: 0.3500 - val_loss: 6.7001 - val_acc: 0.1667
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 3.9235 - acc: 0.3500 - val_loss: 6.6278 - val_acc: 0.1667
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 3.8709 - acc: 0.3500 - val_loss: 6.5567 - val_acc: 0.1667
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 3.8194 - acc: 0.3500 - val_loss: 6.4869 - val_acc: 0.1667
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 3.7690 - acc: 0.3500 - val_loss: 6.4184 - val_acc: 0.1667
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 3.7196 - acc: 0.3500 - val_loss: 6.3512 - val_acc: 0.1667
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 0.6899 - acc: 1.0000 - val_loss: 0.6895 - val_acc: 1.0000
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 0.6895 - acc: 1.0000 - val_loss: 0.6890 - val_acc: 1.0000
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 0.6890 - acc: 1.0000 - val_loss: 0.6885 - val_acc: 1.0000
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 0.6885 - acc: 1.0000 - val_loss: 0.6881 - val_acc: 1.0000
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 0.6881 - acc: 1.0000 - val_loss: 0.6876 - val_acc: 1.0000
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 0.6876 - acc: 1.0000 - val_loss: 0.6871 - val_acc: 1.0000
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 0.6871 - acc: 1.0000 - val_loss: 0.6867 - val_acc: 1.0000
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 10.0572 - acc: 0.0000e+00 - val_loss: 10.5448 - val_acc: 0.0000e+00
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 9.9904 - acc: 0.0000e+00 - val_loss: 10.4748 - val_acc: 0.0000e+00
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 9.9239 - acc: 0.0000e+00 - val_loss: 10.4049 - val_acc: 0.0000e+00
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 9.8575 - acc: 0.0000e+00 - val_loss: 10.3353 - val_acc: 0.0000e+00
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 9.7913 - acc: 0.0000e+00 - val_loss: 10.2660 - val_acc: 0.0000e+00
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 9.7254 - acc: 0.0000e+00 - val_loss: 10.1968 - val_acc: 0.0000e+00
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 9.6597 - acc: 0.0000e+00 - val_loss: 10.1279 - val_acc: 0.0000e+00
# 32/86 [==========>...................] - ETA: 0s[3.9648226674363225, 0.58139534883720934]
# 32/86 [==========>...................] - ETA: 0s[3.9648226674363225, 0.58139534883720934]
# 32/86 [==========>...................] - ETA: 0s[3.9648226674363225, 0.58139534883720934]
# 32/86 [==========>...................] - ETA: 0s[3.9648226674363225, 0.58139534883720934]
# 32/86 [==========>...................] - ETA: 0s[3.9648226674363225, 0.58139534883720934]
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:14: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
