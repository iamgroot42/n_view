# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import numpy as np
np.random.seed(123)

import random
random.seed(123)

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
set_session(tf.Session(config=config))

from keras.utils import plot_model
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, Flatten, BatchNormalization, Dropout, Reshape
from keras.optimizers import Adadelta
from keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import label_binarize
import cv2
import pdb
import progressbar
import os
from scipy import stats
from datasets import get_dataset

# %%
ds = get_dataset("bupa", 0.7, 0.25)
[L_x, L_y], U, [test_x, test_y] = ds.get_data()
U = np.array(U)
n_views = 5
views = []
for ind in range(n_views):
    views.append([np.array(L_x[ind * n_views:(ind + 1) * n_views]), np.array(L_y[ind * n_views:(ind + 1) * n_views])])
for ind in range(n_views):
    print views[ind][0].shape, views[ind][1].shape
# Out:
# (5, 6) (5, 2)
# (5, 6) (5, 2)
# (5, 6) (5, 2)
# (5, 6) (5, 2)
# (5, 6) (5, 2)

# %%
# Define Models
models = []
for ind in range(n_views):
    model = Sequential()
    model.add(Dense(input_shape=(views[ind][0].shape[1],), units=n_attr / 2))
    model.add(Activation('relu'))
    model.add(Dense(units=n_attr/5))
    model.add(Activation('relu'))
    model.add(Dense(units=views[ind][1].shape[1]))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer=Adadelta(), metrics=['accuracy'])
    models.append(model)
print models[0].summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_166 (Dense)            (None, 50)                350
# _________________________________________________________________
# activation_166 (Activation)  (None, 50)                0
# _________________________________________________________________
# dense_167 (Dense)            (None, 20)                1020
# _________________________________________________________________
# activation_167 (Activation)  (None, 20)                0
# _________________________________________________________________
# dense_168 (Dense)            (None, 2)                 42
# _________________________________________________________________
# activation_168 (Activation)  (None, 2)                 0
# =================================================================
# Total params: 1,412.0
# Trainable params: 1,412.0
# Non-trainable params: 0.0
# _________________________________________________________________
# None

# %%
# Train models on Labelled Data
for ind in range(n_views):
    models[ind].fit(views[ind][0], views[ind][1], epochs=100, batch_size = 64, validation_split = 0.2, 
              callbacks=[EarlyStopping(monitor='val_acc', patience=5)])
# Out:
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 0.0028 - acc: 1.0000 - val_loss: 3.6896e-05 - val_acc: 1.0000
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 0.0014 - acc: 1.0000 - val_loss: 2.1160e-05 - val_acc: 1.0000
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 8.8380e-04 - acc: 1.0000 - val_loss: 1.4603e-05 - val_acc: 1.0000
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 6.4743e-04 - acc: 1.0000 - val_loss: 1.1027e-05 - val_acc: 1.0000
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 5.1188e-04 - acc: 1.0000 - val_loss: 8.8215e-06 - val_acc: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 4.2354e-04 - acc: 1.0000 - val_loss: 7.2718e-06 - val_acc: 1.0000
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 3.6129e-04 - acc: 1.0000 - val_loss: 6.1989e-06 - val_acc: 1.0000
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 8.8341 - acc: 0.0000e+00 - val_loss: 13.1037 - val_acc: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 6.8626 - acc: 0.0000e+00 - val_loss: 11.0457 - val_acc: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 4.8736 - acc: 0.0000e+00 - val_loss: 8.9756 - val_acc: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 3.1276 - acc: 0.5000 - val_loss: 7.1821 - val_acc: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 1.9925 - acc: 0.5000 - val_loss: 5.7374 - val_acc: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 1.2769 - acc: 0.5000 - val_loss: 4.5312 - val_acc: 0.0000e+00
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 0.7957 - acc: 0.7500 - val_loss: 3.6029 - val_acc: 0.0000e+00
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00

# %%
# Run Co-Training Algorithm 1
# Simple majority voting over all the classifiers for the unlabelled example
L = views[0]
for ind in range(1, n_views):
    L[0] = np.concatenate([L[0], views[ind][0]], axis = 0)
    L[1] = np.concatenate([L[1], views[ind][1]], axis = 0)
changed = False
pred_modes = None
preds = np.zeros((U.shape[0], n_views))
for ind in range(n_views):
    preds[:, ind] = np.argmax(models[ind].predict(U), axis = 1)
while (not changed):
    pred_modes_new, counts = stats.mode(preds, axis=1)
    if pred_modes_new != pred_modes:
        changed = True
        pred_modes = pred_modes_new
        sel = np.array(np.argmax(pred_modes, axis=0), dtype=int)
        sel_one_hot = label_binarize([pred_modes[sel].squeeze()], classes=range(len(L_y[0]) + 1))[:, :-1]
        print sel_one_hot
        L[0] = np.concatenate([L[0], U[sel]], axis = 0)
        L[1] = np.concatenate([L[1], sel_one_hot], axis = 0)
    for ind in range(n_views):
         models[ind].fit(L[0], L[1], epochs=100, batch_size = 64, validation_split = 0.2, 
              callbacks=[EarlyStopping(monitor='val_acc', patience=5)])
perf = [None for _ in range(n_views)]
for ind in range(n_views):
    perf[ind] = model.evaluate(np.array(test_x), np.array(test_y))
    print perf[ind]
# Out:
# [[0 1]]
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 16.0898 - acc: 0.0000e+00 - val_loss: 13.4317 - val_acc: 0.1667
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 15.9929 - acc: 0.0000e+00 - val_loss: 13.4317 - val_acc: 0.1667
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 15.8946 - acc: 0.0000e+00 - val_loss: 12.9868 - val_acc: 0.1667
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 15.6228 - acc: 0.0000e+00 - val_loss: 11.3177 - val_acc: 0.1667
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 14.2966 - acc: 0.0000e+00 - val_loss: 8.4405 - val_acc: 0.1667
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 11.3859 - acc: 0.0000e+00 - val_loss: 4.9401 - val_acc: 0.1667
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 6.2309 - acc: 0.1000 - val_loss: 3.2377 - val_acc: 0.5000
# Epoch 8/100
# 20/20 [==============================] - 0s - loss: 1.9774 - acc: 0.4500 - val_loss: 2.7427 - val_acc: 0.6667
# Epoch 9/100
# 20/20 [==============================] - 0s - loss: 0.4990 - acc: 0.8000 - val_loss: 2.6157 - val_acc: 0.6667
# Epoch 10/100
# 20/20 [==============================] - 0s - loss: 0.2499 - acc: 0.9500 - val_loss: 2.5297 - val_acc: 0.6667
# Epoch 11/100
# 20/20 [==============================] - 0s - loss: 0.1676 - acc: 0.9500 - val_loss: 2.4617 - val_acc: 0.6667
# Epoch 12/100
# 20/20 [==============================] - 0s - loss: 0.1186 - acc: 0.9500 - val_loss: 2.4032 - val_acc: 0.6667
# Epoch 13/100
# 20/20 [==============================] - 0s - loss: 0.0838 - acc: 0.9500 - val_loss: 2.3532 - val_acc: 0.6667
# Epoch 14/100
# 20/20 [==============================] - 0s - loss: 0.0591 - acc: 0.9500 - val_loss: 2.3117 - val_acc: 0.6667
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 1.3182e-04 - acc: 1.0000 - val_loss: 1.4319 - val_acc: 0.8333
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 1.2356e-04 - acc: 1.0000 - val_loss: 1.4408 - val_acc: 0.8333
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 1.1643e-04 - acc: 1.0000 - val_loss: 1.4504 - val_acc: 0.8333
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 1.1023e-04 - acc: 1.0000 - val_loss: 1.4596 - val_acc: 0.8333
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 1.0462e-04 - acc: 1.0000 - val_loss: 1.4683 - val_acc: 0.8333
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 9.9541e-05 - acc: 1.0000 - val_loss: 1.4767 - val_acc: 0.8333
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 9.4896e-05 - acc: 1.0000 - val_loss: 1.4848 - val_acc: 0.8333
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 7.7486e-07 - acc: 1.0000 - val_loss: 2.4212 - val_acc: 0.8333
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 7.6592e-07 - acc: 1.0000 - val_loss: 2.4227 - val_acc: 0.8333
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 7.5996e-07 - acc: 1.0000 - val_loss: 2.4241 - val_acc: 0.8333
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 7.5400e-07 - acc: 1.0000 - val_loss: 2.4256 - val_acc: 0.8333
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 7.4804e-07 - acc: 1.0000 - val_loss: 2.4271 - val_acc: 0.8333
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 7.4208e-07 - acc: 1.0000 - val_loss: 2.4285 - val_acc: 0.8333
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 7.3612e-07 - acc: 1.0000 - val_loss: 2.4299 - val_acc: 0.8333
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 1.4508 - acc: 0.6000 - val_loss: 0.6672 - val_acc: 0.8333
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 1.1275 - acc: 0.7000 - val_loss: 0.5129 - val_acc: 0.8333
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 0.8974 - acc: 0.7500 - val_loss: 0.3908 - val_acc: 0.8333
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 0.7332 - acc: 0.8000 - val_loss: 0.2980 - val_acc: 0.8333
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 0.6144 - acc: 0.8000 - val_loss: 0.2274 - val_acc: 0.8333
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 0.5260 - acc: 0.8500 - val_loss: 0.1738 - val_acc: 0.8333
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 0.4579 - acc: 0.9000 - val_loss: 0.1339 - val_acc: 0.8333
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 13.4317 - val_acc: 0.1667
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 13.4317 - val_acc: 0.1667
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 13.4317 - val_acc: 0.1667
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 13.4317 - val_acc: 0.1667
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 13.4317 - val_acc: 0.1667
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:14: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 13.4317 - val_acc: 0.1667
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 13.4317 - val_acc: 0.1667
# 32/86 [==========>...................] - ETA: 0s[6.7471097319625182, 0.58139534883720934]
# 32/86 [==========>...................] - ETA: 0s[6.7471097319625182, 0.58139534883720934]
# 32/86 [==========>...................] - ETA: 0s[6.7471097319625182, 0.58139534883720934]
# 32/86 [==========>...................] - ETA: 0s[6.7471097319625182, 0.58139534883720934]
# 32/86 [==========>...................] - ETA: 0s[6.7471097319625182, 0.58139534883720934]
