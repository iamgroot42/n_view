# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import numpy as np
np.random.seed(123)

import random
random.seed(123)

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
set_session(tf.Session(config=config))

from keras.utils import plot_model
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, Flatten, BatchNormalization, Dropout, Reshape
from keras.optimizers import Adadelta
from keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import label_binarize
import cv2
import pdb
import progressbar
import os
from scipy import stats
from datasets import get_dataset

# %%
ds = get_dataset("bupa", 0.7, 0.25)
[L_x, L_y], U, [test_x, test_y] = ds.get_data()
U = np.array(U)
n_views = 5
views = []
for ind in range(n_views):
    views.append([np.array(L_x[ind * n_views:(ind + 1) * n_views]), np.array(L_y[ind * n_views:(ind + 1) * n_views])])
for ind in range(n_views):
    print views[ind][0].shape, views[ind][1].shape
# Out:
# (5, 6) (5, 2)
# (5, 6) (5, 2)
# (5, 6) (5, 2)
# (5, 6) (5, 2)
# (5, 6) (5, 2)

# %%
# Define Models
models = []
for ind in range(n_views):
    model = Sequential()
    model.add(Dense(input_shape=(views[ind][0].shape[1],), units=n_attr / 2))
    model.add(Activation('relu'))
    model.add(Dense(units=n_attr/5))
    model.add(Activation('relu'))
    model.add(Dense(units=views[ind][1].shape[1]))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer=Adadelta(), metrics=['accuracy'])
    models.append(model)
print models[0].summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_181 (Dense)            (None, 50)                350
# _________________________________________________________________
# activation_181 (Activation)  (None, 50)                0
# _________________________________________________________________
# dense_182 (Dense)            (None, 20)                1020
# _________________________________________________________________
# activation_182 (Activation)  (None, 20)                0
# _________________________________________________________________
# dense_183 (Dense)            (None, 2)                 42
# _________________________________________________________________
# activation_183 (Activation)  (None, 2)                 0
# =================================================================
# Total params: 1,412.0
# Trainable params: 1,412.0
# Non-trainable params: 0.0
# _________________________________________________________________
# None

# %%
# Train models on Labelled Data
for ind in range(n_views):
    models[ind].fit(views[ind][0], views[ind][1], epochs=100, batch_size = 64, validation_split = 0.2, 
              callbacks=[EarlyStopping(monitor='val_acc', patience=5)])
# Out:
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 0.2752 - acc: 0.7500 - val_loss: 0.0061 - val_acc: 1.0000
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 0.1360 - acc: 1.0000 - val_loss: 0.0028 - val_acc: 1.0000
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 0.0741 - acc: 1.0000 - val_loss: 0.0017 - val_acc: 1.0000
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 0.0483 - acc: 1.0000 - val_loss: 0.0012 - val_acc: 1.0000
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 0.0354 - acc: 1.0000 - val_loss: 9.2758e-04 - val_acc: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 0.0278 - acc: 1.0000 - val_loss: 7.4665e-04 - val_acc: 1.0000
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 0.0228 - acc: 1.0000 - val_loss: 6.2247e-04 - val_acc: 1.0000
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 0.3286 - acc: 0.7500 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 0.2418 - acc: 0.7500 - val_loss: 0.0022 - val_acc: 1.0000
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 0.1793 - acc: 0.7500 - val_loss: 0.0016 - val_acc: 1.0000
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 0.1351 - acc: 1.0000 - val_loss: 0.0012 - val_acc: 1.0000
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 0.1047 - acc: 1.0000 - val_loss: 0.0010 - val_acc: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 0.0836 - acc: 1.0000 - val_loss: 8.4006e-04 - val_acc: 1.0000
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 0.0687 - acc: 1.0000 - val_loss: 7.2016e-04 - val_acc: 1.0000
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 1.1921e-07 - acc: 1.0000 - val_loss: 1.1921e-07 - val_acc: 1.0000
# Train on 4 samples, validate on 1 samples
# Epoch 1/100
# 4/4 [==============================] - 0s - loss: 7.0217 - acc: 0.0000e+00 - val_loss: 13.5447 - val_acc: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s - loss: 5.7749 - acc: 0.0000e+00 - val_loss: 12.0134 - val_acc: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 0s - loss: 4.5204 - acc: 0.0000e+00 - val_loss: 10.4799 - val_acc: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 0s - loss: 3.2903 - acc: 0.0000e+00 - val_loss: 8.9835 - val_acc: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 0s - loss: 2.1570 - acc: 0.0000e+00 - val_loss: 7.5931 - val_acc: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 0s - loss: 1.2558 - acc: 0.2500 - val_loss: 6.4476 - val_acc: 0.0000e+00
# Epoch 7/100
# 4/4 [==============================] - 0s - loss: 0.7006 - acc: 0.5000 - val_loss: 5.6205 - val_acc: 0.0000e+00

# %%
# Run Co-Training Algorithm 1
# Simple majority voting over all the classifiers for the unlabelled example
L = views[0]
for ind in range(1, n_views):
    L[0] = np.concatenate([L[0], views[ind][0]], axis = 0)
    L[1] = np.concatenate([L[1], views[ind][1]], axis = 0)
changed = False
pred_modes = None
preds = np.zeros((U.shape[0], n_views))
for ind in range(n_views):
    preds[:, ind] = np.argmax(models[ind].predict(U), axis = 1)
while (not changed):
    pred_modes_new, counts = stats.mode(preds, axis=1)
    if pred_modes_new != pred_modes:
        changed = True
        pred_modes = pred_modes_new
        sel = np.array(np.argmax(pred_modes, axis=0), dtype=int)
        sel_one_hot = label_binarize([pred_modes[sel].squeeze()], classes=range(len(L_y[0]) + 1))[:, :-1]
        print sel_one_hot
        L[0] = np.concatenate([L[0], U[sel]], axis = 0)
        L[1] = np.concatenate([L[1], sel_one_hot], axis = 0)
    for ind in range(n_views):
        models[ind].fit(L[0], L[1], epochs=100, batch_size = 64, validation_split = 0.2, 
              callbacks=[EarlyStopping(monitor='val_acc', patience=5)])
perf = [None for _ in range(n_views)]
for ind in range(n_views):
    perf[ind] = model.evaluate(np.array(test_x), np.array(test_y))
    print perf[ind]
# Out:
# [[1 0]]
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 0.0054 - acc: 1.0000 - val_loss: 0.0138 - val_acc: 1.0000
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 0.0052 - acc: 1.0000 - val_loss: 0.0133 - val_acc: 1.0000
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 0.0050 - acc: 1.0000 - val_loss: 0.0127 - val_acc: 1.0000
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 0.0048 - acc: 1.0000 - val_loss: 0.0122 - val_acc: 1.0000
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 0.0046 - acc: 1.0000 - val_loss: 0.0118 - val_acc: 1.0000
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 0.0045 - acc: 1.0000 - val_loss: 0.0113 - val_acc: 1.0000
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 0.0043 - acc: 1.0000 - val_loss: 0.0109 - val_acc: 1.0000
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 0.0215 - acc: 1.0000 - val_loss: 0.0051 - val_acc: 1.0000
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 0.0163 - acc: 1.0000 - val_loss: 0.0040 - val_acc: 1.0000
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 0.0132 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 0.0110 - acc: 1.0000 - val_loss: 0.0027 - val_acc: 1.0000
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 0.0094 - acc: 1.0000 - val_loss: 0.0023 - val_acc: 1.0000
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 0.0082 - acc: 1.0000 - val_loss: 0.0020 - val_acc: 1.0000
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 0.0072 - acc: 1.0000 - val_loss: 0.0018 - val_acc: 1.0000
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 1.6093e-07 - acc: 1.0000 - val_loss: 3.1789e-07 - val_acc: 1.0000
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 1.6093e-07 - acc: 1.0000 - val_loss: 3.1789e-07 - val_acc: 1.0000
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 1.6093e-07 - acc: 1.0000 - val_loss: 3.1789e-07 - val_acc: 1.0000
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 1.6093e-07 - acc: 1.0000 - val_loss: 3.1789e-07 - val_acc: 1.0000
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 1.6093e-07 - acc: 1.0000 - val_loss: 3.1789e-07 - val_acc: 1.0000
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 1.6093e-07 - acc: 1.0000 - val_loss: 3.1789e-07 - val_acc: 1.0000
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 1.6093e-07 - acc: 1.0000 - val_loss: 3.1789e-07 - val_acc: 1.0000
# Train on 20 samples, validate on 6 samples
# Epoch 1/100
# 20/20 [==============================] - 0s - loss: 1.2464 - acc: 0.5500 - val_loss: 0.9166 - val_acc: 0.8333
# Epoch 2/100
# 20/20 [==============================] - 0s - loss: 0.8452 - acc: 0.7000 - val_loss: 0.7208 - val_acc: 0.8333
# Epoch 3/100
# 20/20 [==============================] - 0s - loss: 0.5953 - acc: 0.8000 - val_loss: 0.5821 - val_acc: 0.8333
# Epoch 4/100
# 20/20 [==============================] - 0s - loss: 0.4317 - acc: 0.8000 - val_loss: 0.4778 - val_acc: 0.8333
# Epoch 5/100
# 20/20 [==============================] - 0s - loss: 0.3203 - acc: 0.8500 - val_loss: 0.3969 - val_acc: 0.8333
# Epoch 6/100
# 20/20 [==============================] - 0s - loss: 0.2422 - acc: 0.8500 - val_loss: 0.3335 - val_acc: 0.8333
# Epoch 7/100
# 20/20 [==============================] - 0s - loss: 0.1869 - acc: 0.9000 - val_loss: 0.2835 - val_acc: 0.8333
# 32/86 [==========>...................] - ETA: 0s
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:14: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# [2.3773428118506144, 0.39534883720930231]
# 32/86 [==========>...................] - ETA: 0s[2.3773428118506144, 0.39534883720930231]
# 32/86 [==========>...................] - ETA: 0s[2.3773428118506144, 0.39534883720930231]
# 32/86 [==========>...................] - ETA: 0s[2.3773428118506144, 0.39534883720930231]
# 32/86 [==========>...................] - ETA: 0s[2.3773428118506144, 0.39534883720930231]
